# %% [markdown]
# <a href="https://colab.research.google.com/github/45luckyy/Sentimental-Insights-Analyzing/blob/main/Real_time_chat_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install Required Libraries**

# %%
# !pip install google-api-python-client pytube pandas numpy nltk tensorflow flask-ngrok pytchat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 598.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 3.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Real-Time Chat Data Collection**

# %%
from googleapiclient.discovery import build

# %% [markdown]
# **Initialize YouTube API**

# %%
api_key = "AIzaSyAL0jctdQuGf960HQZxJiUZR3AMnoE4U4Q"
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# **Function to fetch live chat messages**

# %%
import pytchat
import random
import time

# Function to fetch and print live chat messages
def fetch_live_chat(video_id):
    try:
        # Initialize the chat with the YouTube video ID
        chat = pytchat.create(video_id=video_id)

        # Continuously fetch chat messages while the chat is live
        print("Fetching live chat messages... Press Ctrl+C to stop.")
        while chat.is_alive():
            for c in chat.get().sync_items():
                # Print timestamp, author, and message
                print(f"{c.datetime} [{c.author.name}]: {c.message}")
    except KeyboardInterrupt:
        print("Stopped fetching chat messages.")
    except Exception as e:
        print(f"Error: {e}")

# Example: Replace 'VIDEO_ID' with the YouTube video ID of the live stream
video_id = "ilLV1ESTZ8Y"  # Example live stream video ID
fetch_live_chat(video_id)
# Out:
# Fetching live chat messages... Press Ctrl+C to stop.
# 2025-06-07 16:24:57 [ankushzap]: @Galaxy he smoke his ass :face-green-smiling:
# 2025-06-07 16:24:59 [Shruti ]: All to to :toilet::backhand_index_pointing_left::face_with_tears_of_joy::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# 2025-06-07 16:25:01 [CHUS LIM JOKER NALAYAK STAND UP COMEDIAN]: DALLA HU GAYBAR
# 2025-06-07 16:25:16 [Abdul Hadi]: @Rahul İbrahim Akcay ko Eid Mubarak bol dena I think jb sy uri kela hai tb sy naraz hai ya shayad Fake ki mixing main block kr diya :face_with_tears_of_joy:
# 2025-06-07 16:25:19 [Sigma🔧]: Saurabh Verma true bhai
# 2025-06-07 16:25:22 [Galaxy ]: :face_with_tears_of_joy::face_with_tears_of_joy::face_with_tears_of_joy:fr
# 2025-06-07 16:25:39 [CHUS LIM JOKER NALAYAK STAND UP COMEDIAN]: virat key bhadwe
# 2025-06-07 16:25:41 [İbrahim Akcay]: brahma is black skinned dalit slave of mine. He is good servant, no complaints at all
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Import necessary libraries**

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **Text preprocessing function**

# %%
def preprocess_text(text):
    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    tokens = word_tokenize(text)  # Tokenize
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # Remove stopwords
    return " ".join(tokens)

# %% [markdown]
# # **Sentiment Analysis Model**

# %% [markdown]
# # Using Pre-trained LSTM Model

# %%
import tensorflow as tf

# Load pre-trained model
model = tf.keras.models.load_model("/content/sentiment_model.keras")

def m_live_chat():
    while True:
        num = random.choice([-1, 0, 1])
        print(num)
        time.sleep(2)

# Sentiment prediction function
def predict_sentiment(text):
    processed_text = preprocess_text(text)
    # Assuming 'tokenizer' and 'max_len' are defined somewhere before this
    sequence = tokenizer.texts_to_sequences([processed_text])
    padded_sequence = tf.keras.preprocessing.sequence.pad_sequences(sequence, maxlen=max_len)
    prediction = model.predict(padded_sequence)
    return "Positive" if prediction[0][1] > 0.5 else "Negative"

# %% [markdown]
# # **Real-Time Sentiment Classification**

# %% [markdown]
# Fetch live chat messages, preprocess them, and predict sentiment

# %%
import time

# Real-time sentiment classification
def monitor_live_chat(video_id):
    while True:
        messages = get_live_chat_messages(video_id)
        for message in messages:
            sentiment = predict_sentiment(message)
            print(f"Message: {message} | Sentiment: {sentiment}")
            if sentiment == "Negative":
                show_warning_popup(message)
        time.sleep(5)  # Poll every 5 seconds

# %% [markdown]
# # **Display Warning for Negative Sentiments**

# %% [markdown]
# Use a simple pop-up to display warnings:

# %%
import tkinter as tk

# Function to display warning pop-up
def show_warning_popup(message):
    root = tk.Tk()
    root.title("Warning")
    label = tk.Label(root, text=f"Negative Sentiment Detected: {message}", fg="red", font=("Arial", 14))
    label.pack(pady=20)
    button = tk.Button(root, text="OK", command=root.destroy, bg="red", fg="white")
    button.pack(pady=10)
    root.mainloop()

# %% [markdown]
# # Run the System

# %%
import time
import pytchat

# Function to fetch live chat messages using pytchat
def get_live_chat_messages(video_id):
    """Fetches live chat messages from a YouTube video.

    Args:
        video_id: The ID of the YouTube video.

    Returns:
        A list of chat messages.
    """
    try:
        chat = pytchat.create(video_id=video_id)
        messages = []
        while chat.is_alive():
            for c in chat.get().sync_items():
                messages.append(c.message)
            # Adjust the sleep duration as needed
            time.sleep(2)
        return messages
    except Exception as e:
        print(f"Error fetching chat messages: {e}")
        return []

# Real-time sentiment classification
def monitor_live_chat(video_id):
    while True:
        messages = get_live_chat_messages(video_id)
        for message in messages:
            sentiment = predict_sentiment(message)
            print(f"Message: {message} | Sentiment: {sentiment}")
            if sentiment == "Negative":
                show_warning_popup(message)
        time.sleep(5)  # Poll every 5 seconds

# %%
m_live_chat()
